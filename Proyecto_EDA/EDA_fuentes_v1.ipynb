# %% [markdown]
# ![Pan](img/Imagen_principal_proyecto_EDA_Pan.jpg)

# %% [markdown]
# # Introducción al análisis:
#
# En el proyecto que se pretende desarrollar se persigue conocer cuál es el indicador que mayor incidencia tiene en el precio del pan.
# El pan forma parte de la llamada cesta de la compra y, por lo tanto, tiene influencia directa en el Índice de Precios al Consumidor (IPC), ya que el IPC mide la variación del precio de una cesta de bienes y servicios representativa del consumo de los hogares.
# El precio del pan, como el de otros productos, se tiene en cuenta en el cálculo del IPC para reflejar el coste total de la cesta y su evolución.
#
# A lo largo de este proyecto vamos a analizar los factores que pueden influir en el precio del pan considerando el aumento significativo que ha experimentado en los últimos años, así como su impacto directo en el poder adquisitivo de la población en España. En este sentido, vamos a plantear varias hipótesis bajo los supuestos de la identificación de algunos de los principales factores que se han considerado más relevantes, tales como:
# - Los factores externos coyunturales derivados de la situación geopolítica mundial.
# - Las nuevas tendencias en los hábitos de consumo.
# - El cambio climático.
# - La política comunitaria en la UE.

# %% [markdown]
# ## Hipótesis planteadas:
#
# La receta del pan es sencilla : harina y agua.
# Vamos a centrar nuestro estudio en la materia prima principal para la elaboración del pan como base de nuestro análisis: la HARINA.
#
# A continnuación se enumeran las hipótesis del estudio:
#
# 1. ¿Ha sido la guerra de Ucrania el principal factor en la tendencia alcista del precio del pan?
# 2. ¿Es Juan Roig responsable directo de la tendencia alcista del precio del pan?
# 3. ¿Son las políticas de Ursula von der Leyen las que han influido de forma directa en el precio de la barra de pan?
# 4. ¿Ha sido el cambio climático en principal factor en la subida del precio del trigo?

# %% [markdown]
# # Expectativas del estudio:
#
# Si bien se espera que todas las hipótesis planteadas arrojen datos sobre su impacto directo en el precio de la barra del pan, con este estudio se pretende conocer cuál de los indicadores que se han considerado tiene mayor influencia sobre el precio del trigo como materia prima principal en la elaboración del pan.
# Del mismo modo, también se pretende concienciar sobre la importancia de los productos que inciden en la cesta de la compra, no sólo desde un punto de vista económico, sino desde un punto de vista más humanista en el que pueden influir nuestros hábitos de consumo, la productividad de la tierra y los nutrientes y su impacto en las enfermedades de la sociedad occidental, el impacto del cambio climático en la producción de los alimentos, ... etc.
#
# La industria de la alimentación está en constante innovación para aumentar la productividad de las cosechas y poder atender la demanda de una población creciente en el que el pan supone uno de los principales alimentos. Además, otra industria está emergiendo con fuerza en los últimos tiempos: la nutrición encapsulada.
#
# ¿Es posible que estemos cada vez más cerca de esa realidad distópica que presentaba George Orwell en su novela 1984 que reproduce una sociedad controlada incapaz de pensar críticamente mientras consume sucedáneos de carne o chocolate, anticipando una época de suplencias de un café sin cafeina, alimentación sin comida, ...?

# %% [markdown]
# ### Pan : receta :
#
# Los ingredientes básicos, y necesarios para la elaboración del pan son solo dos: harina y agua.
# La sal es un componente opcional que se emplea para dar sabor y fortalecer la masa.

# %% [markdown]
# ### Tipos de trigo:
#
# El trigo es uno de los cereales más consumidos en todo el mundo y es un alimento básico en muchas culturas. Sin embargo, no todo el trigo se crea igual. Hay dos tipos principales de trigo: duro y blando.
#
# - TRIGO DURO:
# El trigo duro, también conocido como trigo duro, es una variedad de trigo que tiene un alto contenido de proteínas y se usa típicamente para hacer productos que requieren un fuerte desarrollo de gluten. Estos incluyen pasta, pan y cuscús. El trigo duro generalmente se cultiva en regiones áridas y es capaz de soportar condiciones ambientales adversas, lo que lo convierte en un cultivo robusto.
# Una de las características clave del trigo duro es su alto contenido de proteínas. Esta proteína es lo que le da fuerza al trigo duro y lo hace ideal para hacer productos como pasta y pan. El trigo duro también tiene un mayor contenido de gluten que el trigo blando, lo que lo hace más adecuado para productos que requieren un fuerte desarrollo de gluten.
# Otro beneficio del trigo duro es que tiene una vida útil más larga que el trigo blando. Esto se debe a que el alto contenido de proteínas del trigo duro ayuda a conservar el grano y evita que se eche a perder.
#
# - TRIGO BLANDO:
# El trigo blando, también conocido como trigo común, es una variedad de trigo que tiene un contenido de proteína más bajo y generalmente se usa para hacer productos como tortas, pasteles y galletas saladas. El trigo blando generalmente se cultiva en climas más templados y tiene una temporada de crecimiento más corta que el trigo duro.
# A diferencia del trigo duro, el trigo blando tiene un contenido de proteína más bajo y un contenido de gluten más bajo. Esto lo hace más adecuado para productos que requieren una textura más tierna, como tortas y pasteles.
# El trigo blando también es más versátil que el trigo duro y se puede utilizar en una amplia variedad de productos. Además de pasteles y pastas, el trigo blando se usa a menudo en productos como galletas dulces y saladas y cereales para el desayuno.
#
# https://es.wikipedia.org/wiki/Pan#:~:text=Los%20ingredientes%20b%C3%A1sicos%2C%20y%20necesarios,sabor%20y%20fortalecer%20la%20masa.

# %% [markdown]
# ### Precio del pan :
#
# IPCA: El Índice de Precios de Consumo Armonizado (IPCA) es un indicador de inflación común que permite comparaciones entre los países de la Unión Europea.
# El IPCA mide la variación de precios de los bienes y servicios para comparar entre países, y el pan es uno de los elementos que componen este índice.
#
# El IPCA de cada país cubre las parcelas que superan el uno por mil del total de gastos de la cesta de la compra nacional. En lo que se refiere a la cobertura de los bienes y servicios incluidos en la cesta de la compra, el IPC incorpora, desde la entrada en vigor de la base 2016 los juegos de azar, que no forman parte del IPCA.
#
# IPCA en septiembre de 2025: 128.76%.
# El valor del IPCA de 'pan' para España en Septiembre de 2025 fue de 128.76%, bajando un -0.27 con respecto al mes previo.
#
# El peso del índice 'pan' en la economía española en el año 2022 representa un 1.39% del total del gasto de la cesta de la compra nacional.
#
# Este índice responde a la siguiente estructura dentro de la ECOICOP: clase Pan y cereales, subgrupo Productos alimenticios y grupo Alimentos y bebidas no alcohólicas.

# %% [markdown]
# ## Fuentes de datos:
#
# - https://ec.europa.eu/taxation_customs/dds2/taric/taric_consultation.jsp?Lang=en
# - https://trade.ec.europa.eu/access-to-markets/es/home
# - https://trade.ec.europa.eu/access-to-markets/es/statistics
# - https://agridata.ec.europa.eu/extensions/DashboardCereals/CerealsProduction.html
# - https://ec.europa.eu/eurostat/databrowser/view/prc_hicp_midx__custom_18787137/default/table
# - https://observatorioprecios.es/ipca/alimentos-y-bebidas-no-alcoholicas#tab2
# - https://opendata.aemet.es/centrodedescargas/productosAEMET?
# - https://www.aemet.es/es/datos_abiertos/estadisticas/estadistica_meteorofenologicas
#
# * Power BI : https://www.mapa.gob.es/es/estadistica/temas/estadisticas-agrarias/economia/powerbi-precios-medios-nacionales

# %%
# Importamos las librerías que vamos a utilizar: 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import os
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
""" 
Para las hipótesis planteadas, vamos a tomar como origen de datos la BBDD de la balanza comercial del Eurobarómetro principalmente.
Se considera una base de datos fiable y actualizada. 
La BBDD está en formato excel - .xlsx - pestaña del archivo: Wheat_IMPORT_2015-25.
"""

ruta = 'BBDD/Data_project/Balance_Export_Import/EU_Wheat_IMPORT_Data_SP.xlsx'
df_import = pd.read_excel(ruta, sheet_name='Wheat_IMPORT_2015-25')

# %%
# Vamos a realizar la comprobación de la ruta: 
print(os.getcwd())  
print(os.path.exists('BBDD/Data_project/Balance_Export_Import/EU_Wheat_IMPORT_Data_SP.xlsx'))
# Out:
# c:\Users\Usuario\Desktop\GIT_Hub_HF\GIT-HUB-HF\Proyecto_EDA
# True

# %%
"""  
Como primer paso, vamos a visualizar en pantalla la estructura de la matriz de datos (df).
Primero vamos a depurar la BBDD de las importaciones y más adelante consideraremos la integración de los datos de las exportaciones (si procede), 
y que mantienen la misma estructura y nomenclatura. 
"""

df_import.head()
# Out:
#      Flow Marketing Year Month  Month Order in MY Month Date Member State  \
# 0  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 1  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 2  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 3  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 4  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
#
#               Partner Product Group  Product Code (CN)  \
# 0           Argentina  Common wheat           11010015
# 1              Brazil   Durum Wheat           11010011
# 2              Canada   Durum Wheat           10011900
# 3  Dominican Republic   Durum Wheat           11031110
# 4               India  Common wheat           11010015
#
#    Quantity in tonnes (grain equivalent)  Value in thousand euro
# 0                                0.73980                   0.363
# ...

# %%
df_import.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2072 entries, 0 to 2071
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Flow                                   2072 non-null   object
#  1   Marketing Year                         2072 non-null   object
#  2   Month                                  2072 non-null   object
#  3   Month Order in MY                      2072 non-null   int64
#  4   Month Date                             2072 non-null   datetime64[ns]
#  5   Member State                           2072 non-null   object
#  6   Partner                                2072 non-null   object
#  7   Product Group                          2072 non-null   object
#  8   Product Code (CN)                      2072 non-null   int64
#  9   Quantity in tonnes (grain equivalent)  2072 non-null   float64
# ...

# %% [markdown]
# # Ayuda df import:
#
# Índice de los principales indicadores de acuerdo con la visualización del df y el método info:
# - 2072 rows × 11 columns
# - No hay datos nulos
# - Tenemos un valor date
#
# ## Observaciones / Notas:
# - Según las investigaciones realizadas, la cosecha de cereales comienza en julio. Por ese motivo
# la columna "Marketing Year" tiene una estructura de índice mensual distinto al año natural.
# - El análisis de datos puede variar dependiendo del código arancelario que estemos evaluando.

# %% [markdown]
# # Hipótesis 1:
# ¿Es ESP autosuficiente para atender la demanda de productos elaborados con trigo?
#
# - Debemos analizar si ESP importa cereales tipo trigo y discriminar si este cereal es para siembra o para consumo.
# - Si existe importaciones y éstas son de trigo distinto del de siembra, se considerará probada la hipótesis.

# %%
"""  
La BBDD contiene la referencia al código arancelario de importación del cereal (trigo). Sin embargo, no se detalla su descripción. 
La columna "Product Code (CN) representa el número arancelario correpondiente con la importación de los tipos de valores.
Si bien se ha obtenido el dato estadístico del trigo, puede existir una subclasificación que puede afectar a las hipótesis. 
Vamos a revisar cuántos tipos hay para poder realizar una clasificación adecuada. 
"""
df_import['Product Code (CN)'].unique()
# Out:
# array([11010015, 11010011, 10011900, 11031110, 10019900, 10019190,
#        10019120, 10011100, 11031190])

# %%
df_import['Product Code (CN)'].value_counts()
# Out:
# Product Code (CN)
# 11010011    586
# 10019900    494
# 11010015    444
# 10011900    181
# 11031110    130
# 10019120     88
# 10011100     55
# 10019190     50
# 11031190     44
# Name: count, dtype: int64

# %% [markdown]
# ## Observaciones tipo de cereal importado:
#
# - Como podemos observar, los datos están concentrados.
# - Para valorar el dato a discriminar debemos relacionar el campo Product Code con su descripción.
# - También analizaremos su valor en relación con las toneladas importadas y el valor de las importaciones realizadas.

# %%
""""
Vamos a visualizar la pestaña de la tabla de datos que queremos integrar a la base de datos de origen, y 
relacionar los dtaos (id HS code) para obtener la descripción y eliminar errores en la interpretación del análisis: 
"""
ruta = 'BBDD/Data_project/Balance_Export_Import/HS_code.xlsx'
df_hs = pd.read_excel(ruta, sheet_name='HS_Code')

# %%
df_hs
# Out:
#     HS code                                       Description   \
# 0  11010015  Productos de la molinería; malta; almidón y fé...
# 1  11010011  Productos de la molinería; malta; almidón y fé...
# 2  11031190  Productos de la molinería; malta; almidón y fé...
# 3  11031110  Productos de la molinería; malta; almidón y fé...
# 4  10019900                                           Cereales
# 5  10019190                                           Cereales
# 6  10019120                                           Cereales
# 7  10011900                                           Cereales
# 8  10011100                                           Cereales
#
#                                  Subcategoría              Item description
# 0  Harina de trigo o de morcajo (tranquillón)  De trigo blando y de escanda
# 1  Harina de trigo o de morcajo (tranquillón)                 De trigo duro
# 2                           Grañones y sémola  De trigo blando y de escanda
# ...

# %% [markdown]
# ## Observaciones y notas:
# Como podemos observar, se distingue entre productos de molinería y otros celeales.
# Así mismo, es igualmente importante considerar la columna "Item description" ya que identifica la segregación
# de los datos entre cereales importados para la siembra y los demás.
# Para nuestro análisis, queremos identificar el valor de las importaciones de los cereales distintos a su uso para la siembra.

# %%
df_hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   HS code           9 non-null      int64
#  1   Description       9 non-null      object
#  2   Subcategoría      9 non-null      object
#  3   Item description  9 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 420.0+ bytes

# %% [markdown]
# ## Observaciones y notas:
# - Tenemos el id común HS code:
#     - En el primer df se denomina "Product Code (CN)
#     - En el segundo df se denomina "HS code"

# %%
# Vamos a incluir la subcategoría 1 = "Description" en la tabla principal: 

df_import['Description'] = df_import['Product Code (CN)'].map(df_hs.set_index('HS code')['Description '])

# %%
# Vamos a incluir la subcategoría 2 = "Item description" en la tabla principal: 

df_import['Item description'] = df_import['Product Code (CN)'].map(df_hs.set_index('HS code')['Item description'])

# %%
df_import.head()
# Out:
#      Flow Marketing Year Month  Month Order in MY Month Date Member State  \
# 0  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 1  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 2  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 3  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 4  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
#
#               Partner Product Group  Product Code (CN)  \
# 0           Argentina  Common wheat           11010015
# 1              Brazil   Durum Wheat           11010011
# 2              Canada   Durum Wheat           10011900
# 3  Dominican Republic   Durum Wheat           11031110
# 4               India  Common wheat           11010015
#
#    Quantity in tonnes (grain equivalent)  Value in thousand euro  \
# 0                                0.73980                   0.363
# ...

# %%
df_import.columns
# Out:
# Index(['Flow', 'Marketing Year', 'Month', 'Month Order in MY', 'Month Date',
#        'Member State', 'Partner', 'Product Group', 'Product Code (CN)',
#        'Quantity in tonnes (grain equivalent)', 'Value in thousand euro',
#        'Description', 'Item description'],
#       dtype='object')

# %% [markdown]
# ## Observaciones y notas:
# Para un análisis más detallado, se considera adecuado incluir nuevas columnas en el df - columnas calculadas:
# - Valor total en €.
# - Valor de €/ton.
# - Valor €/kg.

# %%
df_import['Total value €'] = df_import['Value in thousand euro']*1000
df_import['Total value €'] = df_import['Total value €'].round(2)

# %%
df_import['€/tonelada'] = df_import['Total value €'] / df_import['Quantity in tonnes (grain equivalent)']
df_import['€/tonelada'] = df_import['€/tonelada'].round(2)

# %%
df_import['€/kg'] = df_import['Total value €'] / (df_import['Quantity in tonnes (grain equivalent)'] * 1000)
df_import['€/kg'] = df_import['€/kg'].round(2)

# %%
# Comprobamos la integración de las nuevas columnas: 
df_import.columns
# Out:
# Index(['Flow', 'Marketing Year', 'Month', 'Month Order in MY', 'Month Date',
#        'Member State', 'Partner', 'Product Group', 'Product Code (CN)',
#        'Quantity in tonnes (grain equivalent)', 'Value in thousand euro',
#        'Description', 'Item description', 'Total value €', '€/tonelada',
#        '€/kg'],
#       dtype='object')

# %%
# Vamos a realizar la agrupación de datos de Item description para ver el peso de las importaciones de cereales distintos a la siembra: 

df_grouped = df_import.groupby('Item description')['Quantity in tonnes (grain equivalent)'].sum().sort_values()

# Creamos un gráfico de barras horizontales

df_grouped.plot(kind='barh', color='#32CD32')
plt.xlabel('Quantity in tonnes (grain equivalent)')
plt.ylabel('Item description')
plt.title('Valor acumulado por HS Code')
plt.show;

from IPython.display import FileLink
plt.savefig('Valor_acumulado_HS_code.png', dpi=300, bbox_inches='tight')
FileLink('Valor_acumulado_HS_code.png')
# Out:
# c:\Users\Usuario\Desktop\GIT_Hub_HF\GIT-HUB-HF\Proyecto_EDA\Valor_acumulado_HS_code.png

# %% [markdown]
# ## Observaciones y notas:
# Aunque, a priori, parece claro que las importaciones están muy concentradas en un valor, vamos a intentar representar los valores anualizados para evitar que haya una circunstancia excepcional que esté distorsionando el análisis.

# %%
items = df_import['Item description'].unique()
greens = plt.cm.Greens(np.linspace(0.4, 0.9, len(items)))
color_map = {item: greens[i] for i, item in enumerate(items)}

plt.figure(figsize=(14,10))

color_map = {}
for i, item in enumerate(items):
    if item == "Los demás":
        color_map[item] = '#DFFF00'  
    else:
        color_map[item] = greens[i]

for item in items:
    subset = df_import[df_import['Item description'] == item].sort_values('Marketing Year')
    plt.scatter(
        subset['Marketing Year'],
        subset['Quantity in tonnes (grain equivalent)'],
        color=color_map[item],
        alpha=0.7,
        label=item)
    
plt.xlabel('Marketing Year')
plt.ylabel('Quantity in tonnes (grain equivalent)')
plt.title('Dispersión de Quantity por Marketing Year y Item')
plt.legend(title='Item description', bbox_to_anchor=(1.05, 1), loc='upper left');

# %% [markdown]
# ## Observaciones y notas:
# Se puede apreciar claramente que el item "Los demás" es el artículo con mayor volumen de importaciones.
# Adicionalmente, en el gráfico se puede observar el incremento en el volumen de tonelas importadas que ha experimentado España (en adelante, ESP) en el último período (desde el ejercicio 2020/2021).
# Podemos considerar que el ejercicio 2021/2022 fue atípico derivado de la situación de pandemia originada por el COVID-19 (la declaración de la pandemia fue el 11 de marzo de 2020, pero ya desde enero se había declarado la epidemia,     y que tuvo como consecuencia la paralización del comercio internacional).
# Del mismo modo, se observa en el gráfico el balance de la evolución del comercio exterior de España desde la irrupción del COVID-19, y hasta la invasión rusa de Ucrania.
# Pudiera parecer, a priori, evaluable que la invasión de Ucrania también ha tenido su impacto en las importaciones de cereal a ESP. Sin embargo, la situación geopolítica no debiera ser concluyente en este análisis ya que siendo Ucrania considerada "el granero" de Europa, una situación de crisis provocada por la guerra pudiera tener múltiples consecuencias:
# - Paralización de su comercio.
# - Disminución de su capacidad productiva.
# - Menor competitividad derivada de el aumento de los costos por la sanción de Rusia al comercio internacional a través del cierre de los puertos ucranianos en el Mar Negro, y que ha interrumpido el tránsito marítimo y encarecido los costes de las materias primas.

# %%
# Vamos a agrupar por tipo producto importado y sumar su valor en cantidad de toneladas para ver la distribución de los datos: 
df_cereales_acum = df_import.groupby('Description', as_index=False)['Quantity in tonnes (grain equivalent)'].sum()
df_cereales_acum
# Out:
#                                          Description  \
# 0                                           Cereales
# 1  Productos de la molinería; malta; almidón y fé...
#
#    Quantity in tonnes (grain equivalent)
# 0                           2.318086e+07
# 1                           4.522197e+04

# %%
# Vamos a calcular el porcentaje del total para mejorar el análisis de forma resumida (pareto): 
total = df_cereales_acum['Quantity in tonnes (grain equivalent)'].sum()
df_cereales_acum['% del total'] = df_cereales_acum['Quantity in tonnes (grain equivalent)'] / total * 100
df_cereales_acum['% acumulado'] = df_cereales_acum['% del total'].cumsum()
df_cereales_acum
# Out:
#                                          Description  \
# 0                                           Cereales
# 1  Productos de la molinería; malta; almidón y fé...
#
#    Quantity in tonnes (grain equivalent)  % del total  % acumulado
# 0                           2.318086e+07    99.805297    99.805297
# 1                           4.522197e+04     0.194703   100.000000

# %% [markdown]
# ## Observaciones y notas:
# Vamos a tomar la decisión de realizar un primer filtro en el df eliminando del análisis los productos de molinería que no son representativos.

# %%
# Vamos a filtrar el df principal - df_import - y solo dejar las filas donde Description == "Cereales"
df_cereales = df_import[df_import['Description'] == 'Cereales']

# %%
# Ahora vamos a analizar el segundo nivel (subcategoría del filtro celeales): 

distribucion_volumen = (df_cereales.groupby('Item description', as_index=False)['Quantity in tonnes (grain equivalent)'].sum())
total_volumen = distribucion_volumen['Quantity in tonnes (grain equivalent)'].sum()
distribucion_volumen['% del total'] = (distribucion_volumen['Quantity in tonnes (grain equivalent)'] / total_volumen * 100)
distribucion_volumen
# Out:
#   Item description  Quantity in tonnes (grain equivalent)  % del total
# 0        Los demás                           2.301959e+07    99.304304
# 1     Para siembra                           1.612682e+05     0.695696

# %% [markdown]
# ## Observaciones y notas:
# Adicionalmente, podemos observar que la distribución de los valores está concentrada en la subcategoría de las importaciones del tipo de cereal que es distinto al item para siembra de forma muy significativa.
# En este sentido, se puede considerar que podemos eliminar del análisis los valores de los códigos arancelarios de las importaciones relacionadas con los granos para siembra.
# El impacto de las importaciones no está en el grano de siembra sino en el grano para elaborar los productos derivados del trigo.

# %%
df_import2 = df_cereales[df_cereales['Item description'] == 'Los demás']
df_import2.head()
# Out:
#       Flow Marketing Year Month  Month Order in MY Month Date Member State  \
# 2   IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 7   IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 9   IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 11  IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 12  IMPORT      2019/2020   May                 11 2020-05-01        Spain
#
#                      Partner Product Group  Product Code (CN)  \
# 2                     Canada   Durum Wheat           10011900
# 7             United Kingdom  Common wheat           10019900
# 9             United Kingdom   Durum Wheat           10011900
# 11  United States of America   Durum Wheat           10011900
# 12                 Argentina  Common wheat           10019900
#
#     Quantity in tonnes (grain equivalent)  Value in thousand euro Description  \
# ...

# %%
df_import2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 675 entries, 2 to 2070
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Flow                                   675 non-null    object
#  1   Marketing Year                         675 non-null    object
#  2   Month                                  675 non-null    object
#  3   Month Order in MY                      675 non-null    int64
#  4   Month Date                             675 non-null    datetime64[ns]
#  5   Member State                           675 non-null    object
#  6   Partner                                675 non-null    object
#  7   Product Group                          675 non-null    object
#  8   Product Code (CN)                      675 non-null    int64
#  9   Quantity in tonnes (grain equivalent)  675 non-null    float64
# ...

# %%
# Vamos a agrupar por Product Code (CN) y sumar las columnas de interés.Vemos que el análisis se ha reducido a dos HS codes,
# y que su distribución sigue siendo igualmente concentrada: 

df_product_acumulado = df_import2.groupby('Product Code (CN)').agg(
    {
    'Item description': 'first',
    'Quantity in tonnes (grain equivalent)': 'sum',
    'Value in thousand euro': 'sum',
    })


df_product_acumulado['Quantity in tonnes (grain equivalent)'] = df_product_acumulado['Quantity in tonnes (grain equivalent)'].round(2)
df_product_acumulado['Value in thousand euro'] = df_product_acumulado['Value in thousand euro'].round(2)

df_product_acumulado
# Out:
#                   Item description  Quantity in tonnes (grain equivalent)  \
# Product Code (CN)
# 10011900                 Los demás                             1064278.88
# 10019900                 Los demás                            21955310.24
#
#                    Value in thousand euro
# Product Code (CN)
# 10011900                        371667.98
# 10019900                       4899540.51

# %%
# Vamos a agrupar por Product Code y sumar la cantidad de toneladas importadas
df_product_acumulado = df_import2.groupby(['Product Code (CN)', 'Item description'], as_index=False)['Quantity in tonnes (grain equivalent)'].sum()
df_product_acumulado = df_product_acumulado.sort_values(by='Quantity in tonnes (grain equivalent)', ascending=False)

# Utilizaremos un Pie chart para ver la distribución del volumen: 

plt.figure(figsize=(4,4))
num_colors = len(df_product_acumulado)
colors = plt.cm.Greens(np.linspace(0.4, 0.9, num_colors))

plt.pie(
    df_product_acumulado['Quantity in tonnes (grain equivalent)'],
    labels=df_product_acumulado['Product Code (CN)'],
    autopct='%1.1f%%',
    startangle=140,
    colors=colors
)
plt.title('Distribución del tipo trigo por volumen de toneladas importadas')
plt.show()

# %%
# Vamos a agrupar por Product Code y sumar el volumen en euros del valor de las importaciones: 
df_product_acumulado = df_import2.groupby(['Product Code (CN)', 'Item description'], as_index=False)['Value in thousand euro'].sum()
df_product_acumulado = df_product_acumulado.sort_values(by='Value in thousand euro', ascending=False)

# Utilizaremos un Pie chart para ver la distribución del volumen: 

plt.figure(figsize=(4,4))
num_colors = len(df_product_acumulado)
colors = plt.cm.Greens(np.linspace(0.4, 0.9, num_colors))

plt.pie(
    df_product_acumulado['Value in thousand euro'],
    labels=df_product_acumulado['Product Code (CN)'],
    autopct='%1.1f%%',
    startangle=140,
    colors=colors
)

plt.legend(df_product_acumulado['Item description'],
           title="Item description",
           bbox_to_anchor=(1.05, 1),
           loc='upper left')
plt.title('Distribución del tipo trigo por valor de las toneladas importadas en EUR')
plt.show()

# %%
# Agrupar por Product Code para toneladas
df_ton = df_import2.groupby(['Product Code (CN)', 'Item description'], as_index=False)['Quantity in tonnes (grain equivalent)'].sum()
df_ton = df_ton.sort_values(by='Quantity in tonnes (grain equivalent)', ascending=False)

# Agrupar por Product Code para valor en euros
df_valor = df_import2.groupby(['Product Code (CN)', 'Item description'], as_index=False)['Value in thousand euro'].sum()
df_valor = df_valor.sort_values(by='Value in thousand euro', ascending=False)

# Crear figura con 2 subplots
fig, axes = plt.subplots(1, 2, figsize=(12,6))

# Pie chart toneladas 
num_colors_ton = len(df_ton)
colors_ton = plt.cm.Greens(np.linspace(0.4, 0.9, num_colors_ton))

wedges1, _, autotexts1 = axes[0].pie(
    df_ton['Quantity in tonnes (grain equivalent)'],
    labels=None,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors_ton
)
axes[0].set_title('Distribución por volumen de toneladas importadas')

# Leyenda con Item description
axes[0].legend(wedges1, df_ton['Item description'],
               title="Item description",
               bbox_to_anchor=(1.05, 1),
               loc='upper left')

# Pie chart valor en EUR 
num_colors_valor = len(df_valor)
colors_valor = plt.cm.Greens(np.linspace(0.4, 0.9, num_colors_valor))

wedges2, _, autotexts2 = axes[1].pie(
    df_valor['Value in thousand euro'],
    labels=None,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors_valor
)
axes[1].set_title('Distribución por valor de las toneladas importadas')

# Leyenda con Item description
axes[1].legend(wedges2, df_valor['Item description'],
               title="Item description",
               bbox_to_anchor=(1.05, 1),
               loc='upper left')

plt.tight_layout()
plt.show();

# %%
df_import2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 675 entries, 2 to 2070
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Flow                                   675 non-null    object
#  1   Marketing Year                         675 non-null    object
#  2   Month                                  675 non-null    object
#  3   Month Order in MY                      675 non-null    int64
#  4   Month Date                             675 non-null    datetime64[ns]
#  5   Member State                           675 non-null    object
#  6   Partner                                675 non-null    object
#  7   Product Group                          675 non-null    object
#  8   Product Code (CN)                      675 non-null    int64
#  9   Quantity in tonnes (grain equivalent)  675 non-null    float64
# ...

# %%
df_import2['Item description'].unique()
# Out:
# array(['Los demás'], dtype=object)

# %%
df_import2['Product Code (CN)'].unique()
# Out:
# array([10011900, 10019900])

# %% [markdown]
# ## Observaciones y notas:
# Para ver la evolución del balance de importaciones por años de cosecha (Marketing year), tenemos que considerar las agrupaciones más relevantes una vez hemos eliminado del análisis las referencias de HC code irrelevantes para el análisis.
# Consideramos adecuado analizar tanto el volumen por cantidad (toneladas importadas) como el valor de las imoprtaciones (€/ton).

# %%
# Agrupar por Marketing Year y sumar Total value €
df_acumulado = df_import2.groupby('Marketing Year')['Total value €'].sum()
df_acumulado
# Out:
# Marketing Year
# 2014/2015    2.723486e+08
# 2015/2016    4.381856e+08
# 2016/2017    1.530392e+08
# 2017/2018    2.496324e+08
# 2018/2019    1.640355e+08
# 2019/2020    1.332415e+08
# 2020/2021    1.281181e+08
# 2021/2022    1.848825e+08
# 2022/2023    1.306116e+09
# 2023/2024    1.263641e+09
# 2024/2025    8.766384e+08
# 2025/2026    1.013297e+08
# Name: Total value €, dtype: float64

# %%
df_import2.columns
# Out:
# Index(['Flow', 'Marketing Year', 'Month', 'Month Order in MY', 'Month Date',
#        'Member State', 'Partner', 'Product Group', 'Product Code (CN)',
#        'Quantity in tonnes (grain equivalent)', 'Value in thousand euro',
#        'Description', 'Item description', 'Total value €', '€/tonelada',
#        '€/kg'],
#       dtype='object')

# %%
# Gráfico de barras vertical
plt.figure(figsize=(10, 6))
x = np.arange(len(df_acumulado))
y = df_acumulado.values.flatten()
plt.bar(x, y, color='#32CD32') 

coef = np.polyfit(x, y, 1)
trend = np.poly1d(coef)
plt.plot(x, trend(x), color='darkgreen', linewidth=2, linestyle='--', label='Tendencia')

df_acumulado.plot(kind='bar', color='#32CD32', ax=plt.gca())
plt.xlabel('Marketing Year')
plt.ylabel('Quantity in tonnes (grain equivalent)')
plt.title('Total toneladas importadas acumulado por Marketing Year')
plt.xticks(x, df_acumulado.index, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show();

# %%
# Gráfico de barras vertical
plt.figure(figsize=(10, 6))
x = np.arange(len(df_acumulado))
y = df_acumulado.values.flatten()
plt.bar(x, y, color='#32CD32') 

coef = np.polyfit(x, y, 1)
trend = np.poly1d(coef)
plt.plot(x, trend(x), color='darkgreen', linewidth=2, linestyle='--', label='Tendencia')

df_acumulado.plot(kind='bar', color='#32CD32', ax=plt.gca())
plt.xlabel('Marketing Year')
plt.ylabel('Value in thousand euro')
plt.title('Total valor en miles de las importaciones acumulado por Marketing Year')
plt.xticks(x, df_acumulado.index, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show();

# %%
# Agrupar por Marketing Year y sumar Value in thousand euro
df_evolucion = df_import2.groupby('Marketing Year')['Value in thousand euro'].sum().sort_index()

# Gráfico de línea
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='#32CD32') 

plt.xlabel('Marketing Year')
plt.ylabel('Value in thousand euro')
plt.title('Evolución del valor en miles de las importaciones acumulado por Marketing Year')
plt.xticks(rotation=45)
plt.show();

# %% [markdown]
# # Hipótesis 2:
# Por el momento, se ha demostrado que ESP no es autosuficiente en la producción de materia prima para elaborar el pan, y que sus importaciones se han visto cláramente incrementadas en los últimos años (período desde el 2021/2022 hasta la fecha, especialmente).
# Vamos a ir ahora con la segunda hipótesis:
# ¿La invasión de Rusia ha tenido un impacto directo en las importaciones de cereales y, consecuéntemente en el precio de la materia prima?
# Para este análisis, vamos a revisar los países originarios del trigo importado. En un principio, analizaremos el histórico total para ver si hay cambios en la tendencia de los importadores. Si no es un valor relevante, filtraremos los datos para analizar un período más ajustado (2020-2025).

# %%
# Agrupamos los valores por Partner por toneladas importadas: 

df_pais = df_import2.groupby('Partner', as_index=False)[['Quantity in tonnes (grain equivalent)']].sum()
df_pais = df_pais.sort_values(by='Quantity in tonnes (grain equivalent)', ascending=False)
df_top5 = df_pais.head(5)
df_top5
# Out:
#                      Partner  Quantity in tonnes (grain equivalent)
# 29                   Ukraine                           1.560138e+07
# 30            United Kingdom                           3.103946e+06
# 3                     Canada                           2.333689e+06
# 24                    Russia                           7.214939e+05
# 31  United States of America                           4.120756e+05

# %%
df_pais.columns
# Out:
# Index(['Partner', 'Quantity in tonnes (grain equivalent)'], dtype='object')

# %%
len(df_pais['Partner'])
# Out:
# 32

# %%
plt.figure(figsize=(14, 7))
highlight = ['Ukraine', 'United Kingdom', 'Canada', 'Russia', 'United States of America']
default_color = '#B0B0B0'
highlight_color = '#32CD32'

# Scatter plot: X = Marketing Year, Y = Quantity, color por Partner
partners = df_import2['Partner'].unique()

for partner in partners:
    subset = df_import2[df_import2['Partner'] == partner]

    if partner in highlight:
        marker = 'D'
        color = highlight_color
        size = 100 
    else:
        marker = 'o'
        color = default_color
        size = 50

    plt.scatter(
        subset['Marketing Year'],
        subset['Quantity in tonnes (grain equivalent)'],
        color=color,
        alpha=0.7,
        label=partner,
        marker=marker,
        s=size
    )

plt.xlabel('Marketing Year')
plt.ylabel('Quantity in tonnes (grain equivalent)')
plt.title('Dispersión de Quantity por Partner y Marketing Year')
plt.legend(title='Partner', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
df_filtrado = df_import2[df_import2['Quantity in tonnes (grain equivalent)'] > 100000]

plt.figure(figsize=(14, 7))

partners = df_filtrado['Partner'].unique()

for partner in partners:
    subset = df_filtrado[df_filtrado['Partner'] == partner]
    
    if partner == 'Ukraine':
        color = '#FFCC00'
        size = 100
    else:
        color = '#32CD32'
        size = 70
    
    # Scatter plot:
    plt.scatter(
        subset['Marketing Year'],
        subset['Quantity in tonnes (grain equivalent)'],
        color=color,
        alpha=0.7,
        s=size,
        label=partner
    )


handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), title='Partner', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.xlabel('Marketing Year')
plt.ylabel('Quantity in tonnes (grain equivalent)')
plt.title('Dispersión de Quantity > 100000 por Marketing Year y Partner')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
"""  Prueba PARETO: 
"""

# Agrupar por Partner y sumar Quantity
df_suma = df_import2.groupby('Partner')[['Quantity in tonnes (grain equivalent)', 'Value in thousand euro']].sum()

# Seleccionar top 10
df_top10 = df_suma.sort_values('Quantity in tonnes (grain equivalent)', ascending=False).head(10)
df_top10['% Quantity'] = df_top10['Quantity in tonnes (grain equivalent)'].cumsum() / df_top10['Quantity in tonnes (grain equivalent)'].sum() * 100
df_top10['% Value'] = df_top10['Value in thousand euro'].cumsum() / df_top10['Value in thousand euro'].sum() * 100


# Crear figura
fig, ax1 = plt.subplots(figsize=(12,6))

# Barras horizontales: Quantity
df_top10['Quantity in tonnes (grain equivalent)'].plot(kind='barh', color='skyblue', ax=ax1)
ax1.set_xlabel ('Quantity in tonnes (grain equivalent)')
ax1.set_ylabel ('Partner')
ax1.invert_yaxis()
ax1.grid(axis='x', linestyle='--', alpha=0.5)

# Eje secundario para % acumulado
ax2 = ax1.twiny()
ax2.plot(df_top10['% Quantity'], df_top10.index, color='red', marker='o', linestyle='-', label='% Quantity acumulado')
ax2.plot(df_top10['% Value'], df_top10.index, color='green', marker='o', linestyle='--', label='% Value acumulado')
ax2.set_xlabel('% acumulado')
ax2.legend(loc='lower right')

plt.title('Top 10 Partners: Quantity vs Value acumulados')
# Out:
# Text(0.5, 1.0, 'Top 10 Partners: Quantity vs Value acumulados')

# %%
# Agrupar por Partner
df_pareto = df_import.groupby('Partner', as_index=False)[['Quantity in tonnes (grain equivalent)', 'Value in thousand euro']].sum()

# Ordenar por Value descending
df_pareto = df_pareto.sort_values(by='Value in thousand euro', ascending=False)

# Calcular porcentaje acumulado del valor
df_pareto['cum_percent'] = df_pareto['Value in thousand euro'].cumsum() / df_pareto['Value in thousand euro'].sum() * 100

# Seleccionar Partners que sumen hasta el 80% del valor acumulado
top_partners = df_pareto[df_pareto['cum_percent'] <= 80]['Partner'].tolist()

# Filtrar el DataFrame original solo con estos Partners
df_top = df_import[df_import['Partner'].isin(top_partners)].copy()

# %%
# Seleccionar top 5
df_top5 = df_pais.sort_values(by='Quantity in tonnes (grain equivalent)', ascending=False).head(5)

colors = []
num_partners = len(df_top5)
green_gradient = plt.cm.Greens(np.linspace(0.5, 0.9, num_partners))

for i, partner in enumerate(df_top5['Partner']):
    if partner == 'Ukraine':
        colors.append('#FFD700')
    else:
        colors.append(green_gradient[i])

# Pie chart:
plt.figure(figsize=(8, 8))
plt.pie(
    df_top5['Quantity in tonnes (grain equivalent)'].values, 
    autopct='%1.1f%%', 
    startangle=90, 
    colors=colors,
    textprops={'fontsize': 10})

plt.legend(
    df_top5['Partner'],
    title='Partner', 
    bbox_to_anchor=(1.05, 1), 
    loc='upper left', 
    fontsize=12, 
    title_fontsize=10)

plt.title('Top 5 Partners por Quantity acumulada')
plt.axis('equal')
plt.tight_layout()
plt.show();

# %% [markdown]
# ## Observaciones y notas:
# Podemos concluir que Ucrania ha sido históricamente al mayor socio de ESP para la importaciones de cereales.
# A priori, la producción e importación de esta materia prima agroalimentaria no ha tenido impacto por la invasión de Rusia. Sí parece verse claro el impacto durante la pandemia del COVID-19.
# Aunque en volúmenes más pequeños, el volumen parece muy atomizado por muchos socios, en grándes volúmenes podemos observar que existen tres grandes importadores:
# - Ucrania
# - Canada
# - Reino Unido
#
# Veamos ahora su correlación con el precio por kg.

# %% [markdown]
# # Hipótesis 3:
#
# Aunque pudiera observarse que la invasión de Rusia no ha tenido un impacto directos sobre la producción, parece lógico que sí haya tenido un impacto directo en su coste (la ruta del Mar Negro se ha visto afectada, los medios disponibles en el país se han visto condicionados, el coste del combustible para transportar el grano se ha visto influenciado por la guerra ... etc).

# %%
# Visualizamos los valores del campo "Marketing Year"
sorted(df_import2['Marketing Year'].unique())
# Out:
# ['2014/2015',
#  '2015/2016',
#  '2016/2017',
#  '2017/2018',
#  '2018/2019',
#  '2019/2020',
#  '2020/2021',
#  '2021/2022',
#  '2022/2023',
#  '2023/2024',
#  '2024/2025',
#  '2025/2026']

# %%
df_import2['Mes'] = df_import2['Month Date'].dt.month_name(locale='es_ES')
print(df_import2[['Month Date', 'Mes']].head())
# Out:
#    Month Date    Mes
# 2  2020-06-01  Junio
# 7  2020-06-01  Junio
# 9  2020-06-01  Junio
# 11 2020-06-01  Junio
# 12 2020-05-01   Mayo
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_31408\2501351770.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_fechas = df_import2[['Marketing Year', 'Month Order in MY', 'Mes']]
df_fechas.head()
# Out:
#    Marketing Year  Month Order in MY    Mes
# 2       2019/2020                 12  Junio
# 7       2019/2020                 12  Junio
# 9       2019/2020                 12  Junio
# 11      2019/2020                 12  Junio
# 12      2019/2020                 11   Mayo

# %%
df_acumulado = (df_import2.groupby(['Marketing Year', 'Month Order in MY', 'Mes'], as_index=False)['Value in thousand euro'].sum().sort_values(by=['Marketing Year', 'Month Order in MY']))
df_acumulado['Valor acumulado (mil€k)'] = (df_acumulado.groupby('Marketing Year')['Value in thousand euro'].cumsum())
df_acumulado.head()
# Out:
#   Marketing Year  Month Order in MY         Mes  Value in thousand euro  \
# 0      2014/2015                  1       Julio                1542.992
# 1      2014/2015                  2      Agosto               42875.970
# 2      2014/2015                  3  Septiembre               38720.848
# 3      2014/2015                  4     Octubre               61426.979
# 4      2014/2015                  5   Noviembre               27914.746
#
#    Valor acumulado (mil€k)
# 0                 1542.992
# 1                44418.962
# 2                83139.810
# 3               144566.789
# 4               172481.535

# %%
df_import2['Marketing Year'].value_counts().sort_index()
# Out:
# Marketing Year
# 2014/2015    63
# 2015/2016    76
# 2016/2017    47
# 2017/2018    60
# 2018/2019    60
# 2019/2020    46
# 2020/2021    53
# 2021/2022    57
# 2022/2023    71
# 2023/2024    75
# 2024/2025    60
# 2025/2026     7
# Name: count, dtype: int64

# %%
df_resumen_anual = df_import2.groupby('Marketing Year', as_index=False)[['Value in thousand euro', 'Quantity in tonnes (grain equivalent)']].sum()
df_resumen_anual['Value in thousand euro'] = df_resumen_anual['Value in thousand euro'].round(2)
df_resumen_anual['Quantity in tonnes (grain equivalent)'] = df_resumen_anual['Quantity in tonnes (grain equivalent)'].round(2)
df_resumen_anual
# Out:
#    Marketing Year  Value in thousand euro  \
# 0       2014/2015               272348.64
# 1       2015/2016               438185.63
# 2       2016/2017               153039.19
# 3       2017/2018               249632.40
# 4       2018/2019               164035.50
# 5       2019/2020               133241.51
# 6       2020/2021               128118.13
# 7       2021/2022               184882.47
# 8       2022/2023              1306115.72
# 9       2023/2024              1263641.26
# 10      2024/2025               876638.36
# 11      2025/2026               101329.68
#
#     Quantity in tonnes (grain equivalent)
# 0                              1443166.29
# 1                              2525437.35
# 2                               934031.73
# 3                              1518928.50
# 4                               801771.33
# 5                               731977.75
# 6                               622032.48
# 7                               520416.09
# ...

# %%
df_plot = df_resumen_anual.melt(id_vars='Marketing Year', 
                                value_vars=['Value in thousand euro', 'Quantity in tonnes (grain equivalent)'],
                                var_name='Tipo', value_name='Valor')

plt.figure(figsize=(12,6))
sns.barplot(data=df_plot, x='Marketing Year', y='Valor', hue='Tipo', palette='Set2')
plt.title('Valores acumulados anuales por Marketing Year')
plt.ylabel('Valor acumulado')
plt.show()

# %%
# Agrupar por Partner y Marketing Year
df_resumen_partner_year = df_import2.groupby(
    ['Partner', 'Marketing Year'], as_index=False
)[['Value in thousand euro', 'Quantity in tonnes (grain equivalent)']].sum()

# Redondear si quieres
df_resumen_partner_year['Value in thousand euro'] = df_resumen_partner_year['Value in thousand euro'].round(2)
df_resumen_partner_year['Quantity in tonnes (grain equivalent)'] = df_resumen_partner_year['Quantity in tonnes (grain equivalent)'].round(2)

# Ver resultado
df_resumen_partner_year
# Out:
#                       Partner Marketing Year  Value in thousand euro  \
# 0                     Algeria      2020/2021                  527.86
# 1                   Argentina      2015/2016                 5201.48
# 2                   Argentina      2017/2018                    0.41
# 3                   Argentina      2018/2019                    0.26
# 4                   Argentina      2019/2020                    0.47
# ..                        ...            ...                     ...
# 162  United States of America      2020/2021                 7035.63
# 163  United States of America      2021/2022                10954.20
# 164  United States of America      2022/2023                 7714.68
# 165  United States of America      2023/2024                 8106.58
# 166  United States of America      2024/2025                12518.83
#
#      Quantity in tonnes (grain equivalent)
# 0                                  2514.60
# 1                                 19929.04
# ...

# %%
# Agrupar por Partner
df_partner_total = df_import2.groupby('Partner', as_index=False)['Quantity in tonnes (grain equivalent)'].sum()
# Ordenar de mayor a menor (opcional)
df_partner_total = df_partner_total.sort_values(by='Quantity in tonnes (grain equivalent)', ascending=False)
df_partner_total
# Out:
#                      Partner  Quantity in tonnes (grain equivalent)
# 29                   Ukraine                           1.560138e+07
# 30            United Kingdom                           3.103946e+06
# 3                     Canada                           2.333689e+06
# 24                    Russia                           7.214939e+05
# 31  United States of America                           4.120756e+05
# 25                    Serbia                           3.249075e+05
# 18                   Moldova                           1.993564e+05
# 28                   Türkiye                           1.075803e+05
# 15                Kazakhstan                           9.120204e+04
# 9                      Egypt                           3.587104e+04
# 2                  Australia                           3.436307e+04
# 17                    Mexico                           3.087212e+04
# 1                  Argentina                           1.992932e+04
# ...

# %%
# Agrupar por Partner y sumar la cantidad
df_partner_total = df_import2.groupby('Partner', as_index=False)[
    'Quantity in tonnes (grain equivalent)'
].sum()

# Ordenar de mayor a menor
df_partner_total = df_partner_total.sort_values(by='Quantity in tonnes (grain equivalent)', ascending=False)

# %%
# Porcentaje de cada Partner respecto al total
df_partner_total['Porcentaje'] = df_partner_total['Quantity in tonnes (grain equivalent)'] / df_partner_total['Quantity in tonnes (grain equivalent)'].sum() * 100

# Porcentaje acumulado
df_partner_total['Acumulado (%)'] = df_partner_total['Porcentaje'].cumsum()

# Ver resultado
df_partner_total
# Out:
#                      Partner  Quantity in tonnes (grain equivalent)  \
# 29                   Ukraine                           1.560138e+07
# 30            United Kingdom                           3.103946e+06
# 3                     Canada                           2.333689e+06
# 24                    Russia                           7.214939e+05
# 31  United States of America                           4.120756e+05
# 25                    Serbia                           3.249075e+05
# 18                   Moldova                           1.993564e+05
# 28                   Türkiye                           1.075803e+05
# 15                Kazakhstan                           9.120204e+04
# 9                      Egypt                           3.587104e+04
# 2                  Australia                           3.436307e+04
# 17                    Mexico                           3.087212e+04
# 1                  Argentina                           1.992932e+04
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))

# Barras: cantidad por Partner
sns.barplot(
    data=df_partner_total,
    x='Partner',
    y='Quantity in tonnes (grain equivalent)',
    color='skyblue'
)

# Línea: porcentaje acumulado
plt.twinx()
plt.plot(df_partner_total['Partner'], df_partner_total['Acumulado (%)'], color='red', marker='o', linewidth=2)
plt.ylabel('Acumulado (%)')
plt.title('Análisis Pareto: Quantity por Partner')
plt.xticks(rotation=45)
plt.show()

# %%
# Filtrar filas donde Description es "Cereales"
df_cereales = df_import2[df_import2['Description'] == 'Cereales']

df_cereales
# Out:
#         Flow Marketing Year Month  Month Order in MY Month Date Member State  \
# 2     IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 7     IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 9     IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 11    IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 12    IMPORT      2019/2020   May                 11 2020-05-01        Spain
# ...      ...            ...   ...                ...        ...          ...
# 2059  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2066  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2067  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2068  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2070  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
#
# ...

# %%
df_import2['Rango_quantity'] = pd.cut(
    df_import2['Quantity in tonnes (grain equivalent)'],
    bins=[0, 1000, float('inf')],   # rangos: 0-1000 y >1000
    labels=['0-1000', '>1000'],
    right=True  # el límite superior está incluido
)

# %%
df_import2
# Out:
#         Flow Marketing Year Month  Month Order in MY Month Date Member State  \
# 2     IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 7     IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 9     IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 11    IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 12    IMPORT      2019/2020   May                 11 2020-05-01        Spain
# ...      ...            ...   ...                ...        ...          ...
# 2059  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2066  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2067  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2068  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2070  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
#
# ...

# %%
df_filtrado = df_import2[
    (df_import2['Description'] == 'Cereales') &
    (df_import2['Item description'] == 'Los demás') &
    (df_import2['Rango_quantity'] == '>1000')
]

# %%
df_filtrado
# Out:
#         Flow Marketing Year Month  Month Order in MY Month Date Member State  \
# 11    IMPORT      2019/2020   Jun                 12 2020-06-01        Spain
# 18    IMPORT      2019/2020   May                 11 2020-05-01        Spain
# 20    IMPORT      2019/2020   May                 11 2020-05-01        Spain
# 28    IMPORT      2019/2020   Apr                 10 2020-04-01        Spain
# 30    IMPORT      2019/2020   Apr                 10 2020-04-01        Spain
# ...      ...            ...   ...                ...        ...          ...
# 2050  IMPORT      2020/2021   Aug                  2 2020-08-01        Spain
# 2053  IMPORT      2020/2021   Aug                  2 2020-08-01        Spain
# 2059  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2066  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
# 2067  IMPORT      2020/2021   Jul                  1 2020-07-01        Spain
#
# ...

# %%
df_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365 entries, 11 to 2067
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Flow                                   365 non-null    object
#  1   Marketing Year                         365 non-null    object
#  2   Month                                  365 non-null    object
#  3   Month Order in MY                      365 non-null    int64
#  4   Month Date                             365 non-null    datetime64[ns]
#  5   Member State                           365 non-null    object
#  6   Partner                                365 non-null    object
#  7   Product Group                          365 non-null    object
#  8   Product Code (CN)                      365 non-null    int64
#  9   Quantity in tonnes (grain equivalent)  365 non-null    float64
# ...

# %%
df_filtrado['Month Date'] = pd.to_datetime(df_filtrado['Month Date'])
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_31408\1609397494.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_top5
# Out:
#                      Partner  Quantity in tonnes (grain equivalent)
# 29                   Ukraine                           1.560138e+07
# 30            United Kingdom                           3.103946e+06
# 3                     Canada                           2.333689e+06
# 24                    Russia                           7.214939e+05
# 31  United States of America                           4.120756e+05

# %%
df_filtrado = df_filtrado.sort_values('Month Date').reset_index(drop=True)

# %%
df_import2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 675 entries, 2 to 2070
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Flow                                   675 non-null    object
#  1   Marketing Year                         675 non-null    object
#  2   Month                                  675 non-null    object
#  3   Month Order in MY                      675 non-null    int64
#  4   Month Date                             675 non-null    datetime64[ns]
#  5   Member State                           675 non-null    object
#  6   Partner                                675 non-null    object
#  7   Product Group                          675 non-null    object
#  8   Product Code (CN)                      675 non-null    int64
#  9   Quantity in tonnes (grain equivalent)  675 non-null    float64
# ...

# %%
df_filtrado = df_import2[df_import2['Quantity in tonnes (grain equivalent)'] > 100000]

# %%
ultimo_anio = df_filtrado['Month Date'].max()
primer_anio = ultimo_anio - pd.DateOffset(years=10)
df_ultimos10 = df_filtrado[df_filtrado['Month Date'].between(primer_anio, ultimo_anio)]

# %%
top5_partners = df_ultimos10.groupby('Partner')['Quantity in tonnes (grain equivalent)'] \
                            .sum() \
                            .sort_values(ascending=False) \
                            .head(5) \
                            .index.tolist()

# %%
df_top5 = df_ultimos10[df_ultimos10['Partner'].isin(top5_partners)]

# %%
pivot = df_top5.pivot_table(
    index='Marketing Year',
    columns='Partner',
    values='€/tonelada',
    aggfunc='mean')

cmap = sns.light_palette("green", as_cmap=True)
mask_ukraine = pivot.columns == 'Ukraine'

plt.figure(figsize=(12,6))
ax = sns.heatmap(
    pivot,
    annot=True,
    fmt=".2f",
    cmap=cmap,
    linewidths=0.5,
    linecolor='gray',
    cbar_kws={'label': '€/tonelada'})

for i, col in enumerate(pivot.columns):
    if col == 'Ukraine':
        for y in range(pivot.shape[0]):
            ax.add_patch(plt.Rectangle((i, y), 1, 1, fill=True, color="#FFD700", alpha=0.3))


plt.title('€/kg promedio por mes y grupo de marketing')
plt.xlabel('Partner', fontsize=12)
plt.ylabel('Marketing Year', fontsize=12)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df_top5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 337 entries, 2 to 2070
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Flow                                   337 non-null    object
#  1   Marketing Year                         337 non-null    object
#  2   Month                                  337 non-null    object
#  3   Month Order in MY                      337 non-null    int64
#  4   Month Date                             337 non-null    datetime64[ns]
#  5   Member State                           337 non-null    object
#  6   Partner                                337 non-null    object
#  7   Product Group                          337 non-null    object
#  8   Product Code (CN)                      337 non-null    int64
#  9   Quantity in tonnes (grain equivalent)  337 non-null    float64
# ...

# %%
df_ukraine_2023 = df_import2[
    (df_import2['Partner'] == 'Ukraine') &
    (df_import2['Marketing Year'] == '2023/2024')  # o ajustar si es datetime
]

df_ukraine_2023[['Marketing Year', 'Partner', 'Quantity in tonnes (grain equivalent)', '€/tonelada']]
# Out:
#      Marketing Year  Partner  Quantity in tonnes (grain equivalent)  \
# 1251      2023/2024  Ukraine                             267106.424
# 1268      2023/2024  Ukraine                             496877.514
# 1283      2023/2024  Ukraine                             416920.599
# 1302      2023/2024  Ukraine                             467227.707
# 1315      2023/2024  Ukraine                             489080.899
# 1325      2023/2024  Ukraine                             615149.066
# 1347      2023/2024  Ukraine                             451907.564
# 1368      2023/2024  Ukraine                             384644.753
# 1391      2023/2024  Ukraine                             475495.096
# 1417      2023/2024  Ukraine                             468104.119
# 1436      2023/2024  Ukraine                             272565.074
# 1453      2023/2024  Ukraine                             132671.200
#
#       €/tonelada
# 1251      212.52
# 1268      202.13
# 1283      199.62
# ...

# %%
pivot['€/kg promedio anual'] = pivot['€/kg promedio anual'].round(2)
print(pivot[['€/kg promedio anual']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '€/kg promedio anual'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[310], line 1
# ...

# %%
plt.figure(figsize=(8,5))
sns.barplot(
    data=pivot.reset_index(),
    x='Marketing Year',
    y='€/kg promedio anual',
    palette='Blues_d'
)
plt.title('€/kg promedio anual por Marketing Year')
plt.xlabel('Marketing Year')
plt.ylabel('€/kg promedio anual')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[511], line 2
#       1 plt.figure(figsize=(8,5))
# ----> 2 sns.barplot(
#       3     data=pivot.reset_index(),
#       4     x='Marketing Year',
#       5     y='€/kg promedio anual',
#       6     palette='Blues_d'
#       7 )
#       8 plt.title('€/kg promedio anual por Marketing Year')
#       9 plt.xlabel('Marketing Year')
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(18,6))

# 🔹 Heatmap mensual
sns.heatmap(
    pivot.drop(columns='€/kg promedio anual'),
    annot=True, fmt=".2f",
    cmap="YlGnBu",
    ax=axes[0]
)
axes[0].set_title('€/kg promedio por mes y Marketing Year')
axes[0].set_xlabel('Mes')
axes[0].set_ylabel('Marketing Year')

# 🔹 Barra media anual
sns.barplot(
    data=pivot.reset_index(),
    x='Marketing Year',
    y='€/kg promedio anual',
    palette='Blues_d',
    ax=axes[1]
)
axes[1].set_title('€/kg promedio anual por Marketing Year')
axes[1].set_xlabel('Marketing Year')
axes[1].set_ylabel('€/kg promedio anual')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[363], line 5
#       1 fig, axes = plt.subplots(1, 2, figsize=(18,6))
#       3 # 🔹 Heatmap mensual
#       4 sns.heatmap(
# ----> 5     pivot.drop(columns='€/kg promedio anual'),
#       6     annot=True, fmt=".2f",
#       7     cmap="YlGnBu",
#       8     ax=axes[0]
#       9 )
#      10 axes[0].set_title('€/kg promedio por mes y Marketing Year')
#      11 axes[0].set_xlabel('Mes')
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
# ...

# %%
pivot_country = df_filtrado.pivot_table(
    index=['Marketing Year', 'Partner'],
    columns='Month Order in MY',
    values='€/kg',
    aggfunc='mean'
)

# Calcular media anual por Marketing Year y Partner
pivot_country['€/kg promedio anual'] = pivot_country.mean(axis=1).round(2)

# Ver resultado
print(pivot_country.head())
# Out:
# Month Order in MY          1     2     3     4     5    6     7     8     9  \
# Marketing Year Partner
# 2014/2015      Canada    NaN  0.24   NaN  0.26  0.23  NaN   NaN   NaN   NaN
#                Mexico    NaN   NaN   NaN   NaN   NaN  0.4  0.39  0.30   NaN
#                Russia   0.25  0.22   NaN  0.25  0.23  NaN  0.25  0.22   NaN
#                Serbia    NaN   NaN  0.19   NaN   NaN  NaN   NaN   NaN   NaN
#                Ukraine   NaN  0.18  0.17  0.16   NaN  NaN  0.18  0.17  0.17
#
# Month Order in MY         10  11     12  €/kg promedio anual
# Marketing Year Partner
# 2014/2015      Canada   0.30 NaN  0.265                 0.26
#                Mexico    NaN NaN    NaN                 0.36
#                Russia   0.27 NaN  0.240                 0.24
#                Serbia    NaN NaN    NaN                 0.19
#                Ukraine   NaN NaN    NaN                 0.17

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# -------------------------------
# 1️⃣ Seleccionar solo columnas de interés
# -------------------------------
columnas = [
    'Marketing Year',
    'Partner',
    'Product Group',
    'Quantity in tonnes (grain equivalent)',
    'Total value €',
    '€/kg',
    'Description',
    'Item description',
    'Rango_quantity',
    'Month Date'  # para obtener el mes
]
df_sel = df_import2[columnas]

# -------------------------------
# 2️⃣ Filtrar según criterios y rango >1000
# -------------------------------
df_filtrado = df_sel[
    (df_sel['Description'] == 'Cereales') &
    (df_sel['Item description'] == 'Los demás') &
    (df_sel['Rango_quantity'] == '>1000')
].copy()

# -------------------------------
# 3️⃣ Convertir Month Date a datetime y obtener mes
# -------------------------------
df_filtrado['Month Date'] = pd.to_datetime(df_filtrado['Month Date'])
df_filtrado['Month Order in MY'] = df_filtrado['Month Date'].dt.month

# -------------------------------
# 4️⃣ Agrupar valores acumulados
# -------------------------------
df_grouped = df_filtrado.groupby(
    ['Marketing Year', 'Partner', 'Month Order in MY']
).agg({
    'Total value €': 'sum',
    'Quantity in tonnes (grain equivalent)': 'sum'
}).reset_index()

# Calcular €/kg acumulado
df_grouped['€/kg'] = df_grouped['Total value €'] / (df_grouped['Quantity in tonnes (grain equivalent)'] * 1000)

# -------------------------------
# 5️⃣ Pivot table €/kg promedio
# -------------------------------
pivot = df_grouped.pivot_table(
    index=['Marketing Year', 'Partner'],
    columns='Month Order in MY',
    values='€/kg',
    aggfunc='mean'
)

# -------------------------------
# 6️⃣ Calcular media anual
# -------------------------------
pivot['€/kg promedio anual'] = pivot.mean(axis=1).round(2)

# -------------------------------
# 7️⃣ Visualización combinada
# -------------------------------
fig, axes = plt.subplots(1, 2, figsize=(18,6))

# 🔹 Heatmap mensual
sns.heatmap(
    pivot.drop(columns='€/kg promedio anual'),
    annot=True, fmt=".2f",
    cmap="YlGnBu",
    ax=axes[0]
)
axes[0].set_title('€/kg promedio por mes y Marketing Year/Partner')
axes[0].set_xlabel('Mes')
axes[0].set_ylabel('Marketing Year / Partner')

# 🔹 Barra media anual
sns.barplot(
    data=pivot.reset_index(),
    x='Marketing Year',
    y='€/kg promedio anual',
    hue='Partner',
    palette='Set2',
    ax=axes[1]
)
axes[1].set_title('€/kg promedio anual por Marketing Year y Partner')
axes[1].set_xlabel('Marketing Year')
axes[1].set_ylabel('€/kg promedio anual')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[367], line 20
#       5 # -------------------------------
#       6 # 1️⃣ Seleccionar solo columnas de interés
#       7 # -------------------------------
#       8 columnas = [
#       9     'Marketing Year',
#      10     'Partner',
#    (...)     18     'Month Date'  # para obtener el mes
#      19 ]
# ---> 20 df_sel = df_import2[columnas]
#      22 # -------------------------------
#      23 # 2️⃣ Filtrar según criterios y rango >1000
#      24 # -------------------------------
#      25 df_filtrado = df_sel[
#      26     (df_sel['Description'] == 'Cereales') &
#      27     (df_sel['Item description'] == 'Los demás') &
#      28     (df_sel['Rango_quantity'] == '>1000')
#      29 ].copy()
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(
    data=df_filtrado,
    x='Month',
    y='€/kg',
    hue='Marketing Year'
)
plt.title('€/kg por mes y grupo de marketing')
plt.xlabel('Mes')
plt.ylabel('€/kg')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(
    data=df_filtrado,
    x='Marketing Year',          # columna de número de mes
    y='€/kg',           # valor a representar
    hue='Month',  # columna de agrupación
    marker='o'
)
plt.title('Evolución de €/kg por mes y grupo de marketing')
plt.xlabel('Mes')
plt.ylabel('€/kg')
plt.xticks(range(1,13))  # mostrar todos los meses
plt.legend(title='Grupo de marketing')
plt.grid(True)
plt.show()

# %%
media_por_year = df_import2.groupby('Marketing Year')['€/kg'].mean().reset_index()

print(media_por_year)
# Out:
#    Marketing Year       €/kg
# 0       2014/2015   2.430952
# 1       2015/2016        inf
# 2       2016/2017        inf
# 3       2017/2018   5.055167
# 4       2018/2019  23.953333
# 5       2019/2020        inf
# 6       2020/2021        inf
# 7       2021/2022        inf
# 8       2022/2023  24.177606
# 9       2023/2024  21.434533
# 10      2024/2025  13.599500
# 11      2025/2026   0.267143

# %%
df_import2.describe()
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning:
#
# invalid value encountered in subtract
#
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning:
#
# invalid value encountered in subtract
#        Month Order in MY           Month Date  Product Code (CN)  \
# count         675.000000                  675       6.750000e+02
# mean            6.152593  2020-01-19 07:06:40       1.001775e+07
# min             1.000000  2014-07-01 00:00:00       1.001190e+07
# 25%             3.000000  2017-01-01 00:00:00       1.001190e+07
# 50%             6.000000  2020-03-01 00:00:00       1.001990e+07
# 75%             9.000000  2023-02-15 00:00:00       1.001990e+07
# max            12.000000  2025-08-01 00:00:00       1.001990e+07
# std             3.289513                  NaN       3.546589e+03
#
# ...

# %%
"""  
Si solo quieres traer una columna (como harías con BUSCARV clásico):
df1['Precio'] = df1['Código'].map(df2.set_index('Código')['Precio'])
➡️ Hace lo mismo que:
=BUSCARV(A2, df2!A:B, 2, FALSO)"""

# %%
# Vamos a realizar la comprobación de la ruta: 
print(os.getcwd())  
print(os.path.exists('BBDD/Data_project/Clima_AEMET/2024/TM_MES_2024.csv'))
# Out:
# c:\Users\Usuario\Desktop\GIT_Hub_HF\GIT-HUB-HF\Proyecto_EDA
# True

# %%
# Vamos a depurar los datos de clima 2024 para utilizarlo como ejemplo: 
ruta = 'BBDD/Data_project/Clima_AEMET/2024/TM_MES_2024.csv'
df_clima_24 = pd.read_csv(ruta, sep=';', encoding='ISO-8859-1')
df_clima_24
# Out:
#    Indicativo  31/01/2024  29/02/2024  31/03/2024  30/04/2024  31/05/2024  \
# 0        1387        12.6        13.3        12.3        14.7        15.3
# 1       1387E        10.9        11.9        11.1        13.5        14.4
# 2        1428         9.2        10.3         9.3        13.0        13.3
# 3        8175         8.7         9.8        11.1        14.0        18.1
# 4       8178D         9.2        10.2        11.5        14.6        18.5
# ..        ...         ...         ...         ...         ...         ...
# 90       2422         6.4         8.4         9.8        12.1        14.7
# 91       2539         5.8         7.3         8.2        10.2        12.5
# 92       2614         6.6         9.1        10.3        13.2        15.5
# 93       9390         6.8         8.3        10.2        12.1        15.1
# 94       9434         7.8        10.9        13.2        15.4        18.8
#
#     30/06/2024  31/07/2024  31/08/2024  30/09/2024  31/10/2024  30/11/2024  \
# ...

# %%
df_clima_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Indicativo  95 non-null     object
#  1   31/01/2024  95 non-null     float64
#  2   29/02/2024  95 non-null     float64
#  3   31/03/2024  95 non-null     float64
#  4   30/04/2024  95 non-null     float64
#  5   31/05/2024  93 non-null     float64
#  6   30/06/2024  93 non-null     float64
#  7   31/07/2024  93 non-null     float64
#  8   31/08/2024  93 non-null     float64
#  9   30/09/2024  93 non-null     float64
#  10  31/10/2024  92 non-null     float64
#  11  30/11/2024  92 non-null     float64
#  12  31/12/2024  93 non-null     float64
#  13  anual       91 non-null     float64
#  14  Año         95 non-null     int64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 11.3+ KB

# %%
df_clima_24 = df_clima_24.dropna(how='all')
df_media_mensual_24 = df_clima_24.mean(numeric_only=True)
df_temp_24 = df_media_mensual_24.reset_index()
df_temp_24.columns = ['Date', 'Temperatura_Media']
df_temp_24 = df_temp_24.drop(df_temp_24.index[[12, 13]])

df_temp_24
# Out:
#           Date  Temperatura_Media
# 0   31/01/2024          10.878947
# 1   29/02/2024          12.016842
# 2   31/03/2024          12.703158
# 3   30/04/2024          15.067368
# 4   31/05/2024          17.356989
# 5   30/06/2024          21.013978
# 6   31/07/2024          24.811828
# 7   31/08/2024          25.495699
# 8   30/09/2024          20.309677
# 9   31/10/2024          17.750000
# 10  30/11/2024          14.753261
# 11  31/12/2024          10.091398

# %%
df_temp_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               12 non-null     object
#  1   Temperatura_Media  12 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 324.0+ bytes

# %%
df_temp_24['Date'] = pd.to_datetime(df_temp_24['Date'], format='%d/%m/%Y')
df_temp_24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               12 non-null     datetime64[ns]
#  1   Temperatura_Media  12 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 324.0 bytes

# %%
df_temp_24
# Out:
#          Date  Temperatura_Media
# 0  2024-01-31          10.878947
# 1  2024-02-29          12.016842
# 2  2024-03-31          12.703158
# 3  2024-04-30          15.067368
# 4  2024-05-31          17.356989
# 5  2024-06-30          21.013978
# 6  2024-07-31          24.811828
# 7  2024-08-31          25.495699
# 8  2024-09-30          20.309677
# 9  2024-10-31          17.750000
# 10 2024-11-30          14.753261
# 11 2024-12-31          10.091398

# %%
# Vamos a depurar los datos de clima 2023 para utilizarlo como ejemplo: 
ruta = 'BBDD/Data_project/Clima_AEMET/2023/TM_MES_2023.csv'
df_clima_23 = pd.read_csv(ruta, sep=';', encoding='ISO-8859-1')
df_clima_23 = df_clima_23.dropna(how='all')
df_media_mensual_23 = df_clima_23.mean(numeric_only=True)
df_temp_23 = df_media_mensual_23.reset_index()
df_temp_23.columns = ['Date', 'Temperatura_Media']
df_temp_23 = df_temp_23.drop(df_temp_23.index[[12, 13]])
df_temp_23['Date'] = pd.to_datetime(df_temp_23['Date'], format='%d/%m/%Y')

df_temp_23
# Out:
#          Date  Temperatura_Media
# 0  2023-01-31           8.937500
# 1  2023-02-28           9.038202
# 2  2023-03-31          13.710345
# 3  2023-04-30          16.323333
# 4  2023-05-31          17.708046
# 5  2023-06-30          22.427273
# 6  2023-07-31          25.274713
# 7  2023-08-31          25.553012
# 8  2023-09-30          21.805618
# 9  2023-10-31          19.358427
# 10 2023-11-30          14.095349
# 11 2023-12-31           9.961905

# %%
# Vamos a depurar los datos de clima 2022 para utilizarlo como ejemplo: 
ruta = 'BBDD/Data_project/Clima_AEMET/2022/TM_MES_2022.csv'
df_clima_22 = pd.read_csv(ruta, sep=';', encoding='ISO-8859-1')
df_clima_22 = df_clima_22.dropna(how='all')
df_media_mensual_22 = df_clima_22.mean(numeric_only=True)
df_temp_22 = df_media_mensual_22.reset_index()
df_temp_22.columns = ['Date', 'Temperatura_Media']
df_temp_22 = df_temp_22.drop(df_temp_22.index[[12, 13]])
df_temp_22['Date'] = pd.to_datetime(df_temp_22['Date'], format='%d/%m/%Y')

df_temp_22
# Out:
#          Date  Temperatura_Media
# 0  2022-01-31           8.838636
# 1  2022-02-28          11.030769
# 2  2022-03-31          11.534884
# 3  2022-04-30          13.282558
# 4  2022-05-31          19.233333
# 5  2022-06-30          22.594382
# 6  2022-07-31          25.821111
# 7  2022-08-31          25.488889
# 8  2022-09-30          21.432558
# 9  2022-10-31          19.673034
# 10 2022-11-30          14.110112
# 11 2022-12-31          11.932184

# %%
# Vamos a depurar los datos de clima 2021 para utilizarlo como ejemplo: 
ruta = 'BBDD/Data_project/Clima_AEMET/2021/TM_MES_2021.csv'
df_clima_21 = pd.read_csv(ruta, sep=';', encoding='ISO-8859-1')
df_clima_21 = df_clima_21.dropna(how='all')
df_media_mensual_21 = df_clima_21.mean(numeric_only=True)
df_temp_21 = df_media_mensual_21.reset_index()
df_temp_21.columns = ['Date', 'Temperatura_Media']
df_temp_21 = df_temp_21.drop(df_temp_21.index[[12, 13]])
df_temp_21['Date'] = pd.to_datetime(df_temp_21['Date'], format='%d/%m/%Y')

df_temp_21
# Out:
#          Date  Temperatura_Media
# 0  2021-01-31           7.897778
# 1  2021-02-28          11.844444
# 2  2021-03-31          11.781928
# 3  2021-04-30          13.891011
# 4  2021-05-31          16.945882
# 5  2021-06-30          20.957609
# 6  2021-07-31          23.364773
# 7  2021-08-31          24.188889
# 8  2021-09-30          21.386517
# 9  2021-10-31          17.259302
# 10 2021-11-30          11.027059
# 11 2021-12-31          10.952809

# %%
# Vamos a depurar los datos de clima 2020 para utilizarlo como ejemplo: 
ruta = 'BBDD/Data_project/Clima_AEMET/2020/TM_MES_2020.csv'
df_clima_20 = pd.read_csv(ruta, sep=';', encoding='ISO-8859-1')
df_clima_20 = df_clima_20.dropna(how='all')
df_media_mensual_20 = df_clima_20.mean(numeric_only=True)
df_temp_20 = df_media_mensual_20.reset_index()
df_temp_20.columns = ['Date', 'Temperatura_Media']
df_temp_20 = df_temp_20.drop(df_temp_20.index[[12, 13]])
df_temp_20['Date'] = pd.to_datetime(df_temp_20['Date'], format='%d/%m/%Y')

df_temp_20
# Out:
#          Date  Temperatura_Media
# 0  2020-01-31           9.235870
# 1  2020-02-29          12.474444
# 2  2020-03-31          12.381609
# 3  2020-04-30          14.629762
# 4  2020-05-31          19.061628
# 5  2020-06-30          20.632941
# 6  2020-07-31          24.895349
# 7  2020-08-31          24.216854
# 8  2020-09-30          21.246154
# 9  2020-10-31          15.833333
# 10 2020-11-30          13.528409
# 11 2020-12-31           9.835227

# %%
df_temperatura = [df_temp_20, df_temp_21, df_temp_22, df_temp_23, df_temp_24]
df_temp_20_24 = pd.concat(df_temperatura, ignore_index=True)
df_temp_20_24
# Out:
#          Date  Temperatura_Media
# 0  2020-01-31           9.235870
# 1  2020-02-29          12.474444
# 2  2020-03-31          12.381609
# 3  2020-04-30          14.629762
# 4  2020-05-31          19.061628
# 5  2020-06-30          20.632941
# 6  2020-07-31          24.895349
# 7  2020-08-31          24.216854
# 8  2020-09-30          21.246154
# 9  2020-10-31          15.833333
# 10 2020-11-30          13.528409
# 11 2020-12-31           9.835227
# 12 2021-01-31           7.897778
# 13 2021-02-28          11.844444
# 14 2021-03-31          11.781928
# 15 2021-04-30          13.891011
# 16 2021-05-31          16.945882
# 17 2021-06-30          20.957609
# 18 2021-07-31          23.364773
# 19 2021-08-31          24.188889
# 20 2021-09-30          21.386517
# 21 2021-10-31          17.259302
# 22 2021-11-30          11.027059
# 23 2021-12-31          10.952809
# 24 2022-01-31           8.838636
# 25 2022-02-28          11.030769
# 26 2022-03-31          11.534884
# ...

# %%
# Supongamos que df_total tiene las columnas 'Date' y 'Temperatura_Media'
df_temp_20_24['Date'] = pd.to_datetime(df_temp_20_24['Date'], dayfirst=True)  # asegurar tipo datetime
df_temp_20_24 = df_temp_20_24.sort_values('Date')

# Gráfico de línea
plt.figure(figsize=(12,6))
plt.plot(df_temp_20_24['Date'], df_temp_20_24['Temperatura_Media'], marker='o', linestyle='-')
plt.title('Temperaturas medias 2020-2024')
plt.xlabel('Fecha')
plt.ylabel('Temperatura Media (°C)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_temp_20_24['Date'] = pd.to_datetime(df_temp_20_24['Date'], dayfirst=True)
df_temp_20_24['Año'] = df_temp_20_24['Date'].dt.year
df_temp_20_24['Mes'] = df_temp_20_24['Date'].dt.month
tabla = df_temp_20_24.pivot_table(values='Temperatura_Media', index='Mes', columns='Año', aggfunc='mean')

# Dibujar heatmap
plt.figure(figsize=(8,6))
sns.heatmap(tabla, annot=True, fmt=".1f", cmap='coolwarm')
plt.title('Mapa de calor de temperaturas medias 2020-2024')
plt.ylabel('Mes')
plt.xlabel('Año')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Asegurarnos que Date es datetime
df_temp_20_24['Date'] = pd.to_datetime(df_temp_20_24['Date'], dayfirst=True)

# Extraer año y mes
df_temp_20_24['Año'] = df_temp_20_24['Date'].dt.year
df_temp_20_24['Mes'] = df_temp_20_24['Date'].dt.month

# Crear tabla pivot para heatmap
tabla = df_temp_20_24.pivot_table(values='Temperatura_Media', index='Mes', columns='Año', aggfunc='mean')

# Calcular la media anual por año
media_anual = df_temp_20_24.groupby('Año')['Temperatura_Media'].mean()

# Crear figura y ejes
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12,10), gridspec_kw={'height_ratios':[2,1]})

# --- Heatmap ---
sns.heatmap(tabla, annot=True, fmt=".1f", cmap='coolwarm', ax=ax1)
ax1.set_title('Mapa de calor de temperaturas medias 2020-2024')
ax1.set_ylabel('Mes')
ax1.set_xlabel('Año')

# --- Línea de medias anuales ---
ax2.plot(media_anual.index, media_anual.values, marker='o', linestyle='-', color='red')
ax2.set_title('Evolución de la temperatura media anual 2020-2024')
ax2.set_xlabel('Año')
ax2.set_ylabel('Temperatura Media (°C)')
ax2.grid(True)

plt.tight_layout()
plt.show()
